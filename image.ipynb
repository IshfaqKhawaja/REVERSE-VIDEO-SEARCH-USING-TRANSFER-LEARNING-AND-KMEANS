# %%
 from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path = '/content/drive/MyDrive/final project mavia/RLVD/'

# %%
import os
# print(dir(os))
os.listdir(path+os.listdir(path)[0])
# Out:
# ['NV_990.mp4',
#  'NV_995.mp4',
#  'NV_99.mp4',
#  'NV_985.mp4',
#  'NV_982.mp4',
#  'NV_986.mp4',
#  'NV_991.mp4',
#  'NV_981.mp4',
#  'NV_984.mp4',
#  'NV_983.mp4',
#  'NV_997.mp4',
#  'NV_968.mp4',
#  'NV_976.mp4',
#  'NV_972.mp4',
#  'NV_969.mp4',
#  'NV_967.mp4',
#  'NV_973.mp4',
#  'NV_980.mp4',
#  'NV_974.mp4',
#  'NV_999.mp4',
#  'NV_97.mp4',
#  'NV_996.mp4',
#  'NV_993.mp4',
#  'NV_987.mp4',
#  'NV_970.mp4',
#  'NV_998.mp4',
#  'NV_992.mp4',
#  'NV_979.mp4',
#  'NV_966.mp4',
#  'NV_98.mp4',
#  'NV_978.mp4',
#  'NV_971.mp4',
#  'NV_975.mp4',
#  'NV_988.mp4',
#  'NV_977.mp4',
#  'NV_956.mp4',
#  'NV_962.mp4',
#  'NV_95.mp4',
#  'NV_954.mp4',
#  'NV_955.mp4',
#  'NV_964.mp4',
#  'NV_953.mp4',
#  'NV_959.mp4',
#  'NV_965.mp4',
#  'NV_950.mp4',
#  'NV_938.mp4',
#  'NV_963.mp4',
#  'NV_958.mp4',
#  'NV_947.mp4',
#  'NV_957.mp4',
#  'NV_960.mp4',
#  'NV_945.mp4',
#  'NV_952.mp4',
#  'NV_961.mp4',
#  'NV_96.mp4',
#  'NV_939.mp4',
#  'NV_951.mp4',
#  'NV_949.mp4',
#  'NV_933.mp4',
# ...

# %%
# !ls '/content/drive/MyDrive/final project mavia/RLVD'
# Out:
# nonviolence  violence

# %%
import os
import cv2
for dir in os.listdir(path):
  # print(dir)
  folder = '/content/drive/MyDrive/Abuzer/data/images/'
  if dir not in os.listdir(folder):
    os.mkdir(folder+dir)
  count=1
  image_path = folder+dir+'/'
  # print(image_path)
  for video in os.listdir(path+dir):
    video_path = path+dir+'/'+video
    # print(video_path)
    vidcap = cv2.VideoCapture(video_path)
    
   
    def getFrame(sec):
        vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
        hasFrames,image = vidcap.read()
        if hasFrames:
            cv2.imwrite(image_path+"image"+str(count)+".jpg", image)     # save frame as JPG file
        return hasFrames
    sec = 0
    frameRate = 1 #//it will capture image in each 0.5 second
    success = getFrame(sec)
    while success:
        count = count + 1
        sec = sec + frameRate
        sec = round(sec, 2)
        success = getFrame(sec)
  # print(dir)
