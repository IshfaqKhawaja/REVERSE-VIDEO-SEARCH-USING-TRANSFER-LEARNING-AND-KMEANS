# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path = '/content/drive/MyDrive/Abuzer/data/Data set/'

import sys
sys.path.append(path)

# %%
# !ls '/content/drive/MyDrive/Abuzer/data/Data set/'
# Out:
# cricket  dance	football  nature  serial

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 15 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 1s (73.4 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 145480 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree '/content/drive/MyDrive/Abuzer/data/Data set/'
# Out:
# /content/drive/MyDrive/Abuzer/data/Data set/
# ├── cricket
# │   ├── cricket 1.mp4
# │   └── cricket 2.mp4
# ├── dance
# │   ├── dance 1.mp4
# │   └── dance 2.mp4
# ├── football
# │   ├── football1.mp4
# │   └── football2.mp4
# ├── nature
# │   ├── nature 1.mp4
# │   └── nature 2.mp4
# └── serial
#     ├── serial 1.mp4
#     └── serial 2.mp4
#
# 5 directories, 10 files

# %%
# !tree '/content/drive/MyDrive/Abuzer/data/images/' -L 2
# Out:
# /content/drive/MyDrive/Abuzer/data/images/
# ├── cricket
# │   ├── image100.jpg
# │   ├── image101.jpg
# │   ├── image102.jpg
# │   ├── image103.jpg
# │   ├── image104.jpg
# │   ├── image105.jpg
# │   ├── image106.jpg
# │   ├── image107.jpg
# │   ├── image108.jpg
# │   ├── image109.jpg
# │   ├── image10.jpg
# │   ├── image110.jpg
# │   ├── image111.jpg
# │   ├── image112.jpg
# │   ├── image113.jpg
# │   ├── image114.jpg
# │   ├── image115.jpg
# │   ├── image116.jpg
# │   ├── image117.jpg
# │   ├── image118.jpg
# │   ├── image119.jpg
# │   ├── image11.jpg
# │   ├── image120.jpg
# │   ├── image121.jpg
# │   ├── image122.jpg
# │   ├── image123.jpg
# │   ├── image124.jpg
# │   ├── image125.jpg
# │   ├── image126.jpg
# │   ├── image127.jpg
# │   ├── image128.jpg
# │   ├── image129.jpg
# │   ├── image12.jpg
# │   ├── image130.jpg
# │   ├── image131.jpg
# │   ├── image132.jpg
# │   ├── image133.jpg
# │   ├── image134.jpg
# │   ├── image135.jpg
# │   ├── image136.jpg
# │   ├── image137.jpg
# ...
